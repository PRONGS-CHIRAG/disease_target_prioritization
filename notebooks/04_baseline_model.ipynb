# %% [markdown]
# # Baseline Model
#
# Context.md §17, §36 — the transparent weighted score first. Check that known Parkinson's targets (LRRK2, SNCA, GBA1, PRKN, PINK1) surface near the top before adding any ML.

# %%
from target_prioritization.config import load_model_config

load_model_config().baseline_weights
