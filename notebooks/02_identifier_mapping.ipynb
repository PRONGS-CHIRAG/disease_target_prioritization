# %% [markdown]
# # Identifier Mapping
#
# Context.md §12 — inspect coverage of the four joins and the records that fail to map. Never discard unmapped records silently (§34).

# %%
from target_prioritization.data import hgnc, gtex, reactome, string_db

lookup, report = hgnc.load_symbol_lookup()
print(report)
