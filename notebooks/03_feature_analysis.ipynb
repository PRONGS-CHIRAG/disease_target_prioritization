# %% [markdown]
# # Feature Analysis
#
# Context.md §14 — distributions, missingness patterns, correlation with the label, and a manual leakage inspection of every feature.

# %%
from target_prioritization.config import load_features

load_features().leakage_guard.denylist
